# %%
from PIL import Image
import matplotlib.pyplot as plt
image = Image.open(r"C:\Users\andek\OneDrive\Desktop\Eashan IITB\Jupyter\Assignment 1 WIDS\sample.jpeg")
plt.imshow(image)
plt.show()

# %%
def process_meme(image_path):
    image = Image.open(image_path)
    width, height = image.size
    print(f"Original dimensions: {width} x {height}")
    grayscale = image.convert('L')
    new_size = (width // 2, height // 2)
    resized = grayscale.resize(new_size)
    resized.save("processed_week1.jpg")
    #return output_path

# %%
process_meme(r"C:\Users\andek\OneDrive\Desktop\Eashan IITB\Jupyter\Assignment 1 WIDS\sample.jpeg")
# Out:
# Original dimensions: 740 x 740
